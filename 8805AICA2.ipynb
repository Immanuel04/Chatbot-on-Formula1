# %%
import nltk
from nltk.chat.util import Chat, reflections

# Define the provided data
responses = {
    "greetings": ["Hello, {} ! How can I assist you Formula 1 today?", "Hi {}, I'm a Formula 1 chatbot. Ask me about teams, drivers, race calendar, technical aspects, and more!", "Welcome back,{}! What can I help you with formula 1?"],
    # Teams information
    'red bull': 'Established in 2005, Red Bull quickly rose to prominence, securing four consecutive drivers and constructors titles from 2010 to 2013.',
    'mercedes': ' Dominant in the hybrid era, Mercedes returned as a works team in 2010, continuing the legacy of its earlier involvement in motorsport.',
    'ferrari': 'Founded in 1929, Ferrari is the oldest and most successful team in F1, with multiple drivers and constructors championships to its name.',
    'aston martin': 'Originally founded as Jordan Grand Prix, the team changed ownership and branding, returning as Aston Martin in 2021 after a long absence.',
    'mclaren': 'McLaren storied history dates back to the 1960s, achieving multiple championships and nurturing legendary drivers like Ayrton Senna and Alain Prost.',
    'alpine': 'Born as Toleman in the 1980s, the team later became Benetton, winning championships with Michael Schumacher, before becoming Renault and eventually Alpine.',
    'williams': 'Founded by Sir Frank Williams in the 1970s, the team achieved great success in the past, winning multiple championships, but has faced challenges in recent years.',
    'haas': 'Debuted in 2016, Haas is the first American team in decades, focusing on collaboration and resource-sharing with Ferrari.',
    'alfa romeo': 'Alfa Romeos F1 involvement has roots in the 1950s. The team currently carries the name of the Italian car manufacturer in partnership with Orlen, a Polish oil company.',
    'alphatauri': 'Previously known as Toro Rosso, the team serves as Red Bull s junior outfit, offering young drivers a chance to enter the F1 world.',

    # Players information
    'max verstappen': 'A Dutch sensation, he s the youngest driver to win a Formula 1 race. His aggressive driving style and fierce determination have made him a 2 time world champion.',
    'sergio perez': 'A Mexican driver celebrated for his tire management and strategic racing approach. He secured his first-ever Formula 1 win during the 2020 season.',
    'lewis hamilton': 'A British racing legend, known for his record-tying seven Formula 1 World Championships and numerous race wins. He s also an advocate for social and environmental causes.',
    'george russell': 'A British driver who caught attention with impressive performances, often filling in for other teams drivers. He is seen as a future star.',
    'charles leclerc': 'A young Monegasque talent, Leclerc impresses with his speed and determination, driving for Scuderia Ferrari in Formula 1',
    'carlos sainz': 'A versatile Spanish driver, Sainz brings experience and consistency to the track, currently partnering with Ferrari to continue his F1 journey.',
    'fernando alonso': 'A Spanish racing icon, Alonso returned to Formula 1 after a braek. He is known for his tenacious racing style and two time world championship.',
    'lance stroll': ' Canadian driver with a strong financial backing, he has shown moments of brilliance and is striving for consistent performance in a competitive field.',
    'lando norris': 'A young British talent, known for his rapid rise through the ranks. He combines speed with a cheerful and approachable demeanor.',
    'oscar piastri': 'An emerging Australian talent, Piastri showcases his potential as a future Formula 1 champion, currently with mclaren f1 team.',
    'estaban ocon': 'A French driver with promising potential, he earned his first victory in a chaotic race at the 2021 hungarian Grand Prix.',
    'pierre gasly': 'A French driver who shocked the racing world by winning the 2020 Italian Grand Prix, showcasing his resilience and skill.',
    'alex albon': 'Alexander Albon, a British-Thai driver, competed with Red Bull Racing he showcased flashes of speed but faced challenges in consistency during his Formula 1 tenure.',
    'logan sargeant': 'Logan Sargeant, an American racing driver, has made his mark in junior categories and is known for his determined approach and pursuit of success in motorsport.',
    'kevin magnussen': 'Known for his aggressive overtaking and competitive spirit, he later joined Haas F1, contributing to the team development.',
    'nico hulkenberg': 'A German driver, showcased consistent performances for various teams but faced challenges in securing a full-time seat despite his skill and experience.',
    'valtteri bottas': 'A Finnish driver with consistent performances, having 10 race wins. He is known for his strong work ethic and team spirit.',
    'guanyu zhou': 'Guanyu Zhou, a Chinese racing talent, has excelled in junior formulas and serves as a alfa romeo driver.',
    'yuki tsunoda': 'A Japanese rookie, Tsunoda made his Formula 1 debut with AlphaTauri, impressing with his speed and adaptability.',
    'daniel ricciardo': 'An Australian driver with a vibrant personality, famous for his "shoey" celebrations. His smooth driving style and overtaking skills have earned him a solid fan base.',

    'race wins': 'Max verstappen has the most race wins in 2023 -- 10 wins in 13 races',
    'formula 1' : 'Formula 1, often abbreviated as F1, is a high-speed, open-wheel motorsport. It involves a series of races known as Grands Prix, held on purpose-built circuits and public roads in various countries.',
    'components' : 'Formula 1 cars are complex machines with various components, including the chassis, engine, gearbox, aerodynamic elements (such as wings), suspension, and tires. These components are designed for high-speed performance and precision.',
    'qualifying' : 'Qualifying sessions determine the starting grid for the race. Drivers compete to set the fastest lap time, with the fastest driver securing the pole position, which is the first starting position on the grid.',
    'pitstop' : 'Pit stops are crucial in F1 races for changing tires, refueling (although less common now), and making adjustments to the car. Quick and well-coordinated pit stops are vital for a team race strategy.',
    'safety car' : 'The Safety Car, often a high-performance road car, is deployed during races when there is a dangerous situation on the track, such as debris or a crash. It leads the cars at a controlled pace to ensure the safety of drivers and track workers.',
    'fastest lap' : 'The fastest lap is the single quickest lap time recorded by a driver during a race. Since 2019, drivers can earn an additional point in the Drivers Championship standings if they achieve the fastest lap while finishing in the top 10 positions.',
    'pole position' : 'The pole position is the starting position on the grid for a race. It is awarded to the driver who sets the fastest time in the qualifying session.',  # Pole position in Formula 1.
    'long' : 'The length of a Formula 1 race varies, but most races have a total distance of around 305 kilometers (190 miles) and last for approximately 90 to 120 minutes.'

}

# Define the patterns for the chatbot
patterns = [
    # Information about Formula 1
    (r'(?:.*)(formula 1)(?:.*)', [responses['formula 1']]),
    (r'(?:.*)(components)(?:.*)', [responses['components']]),
    (r'(?:.*)(qualifying)(?:.*)', [responses['qualifying']]),
    (r'(?:.*)(pitstop)(?:.*)', [responses['pitstop']]),
    (r'(?:.*)(safety car)(?:.*)', [responses['safety car']]),
    (r'(?:.*)(fastest lap)(?:.*)', [responses['fastest lap']]),
    (r'(?:.*)(pole position)(?:.*)', [responses['pole position']]),
    (r'(?:.*)(long)(?:.*)', [responses['long']]),

    # Information about teams
    (r'(?:.*)(red bull)(?:.*)', [responses['red bull']]),
    (r'(?:.*)(mercedes)(?:.*)', [responses['mercedes']]),
    (r'(?:.*)(ferrari)(?:.*)', [responses['ferrari']]),
    (r'(?:.*)(aston martin)(?:.*)', [responses['aston martin']]),
    (r'(?:.*)(mclaren)(?:.*)', [responses['mclaren']]),
    (r'(?:.*)(alpine)(?:.*)', [responses['alpine']]),
    (r'(?:.*)(williams)(?:.*)', [responses['williams']]),
    (r'(?:.*)(haas)(?:.*)', [responses['haas']]),
    (r'(?:.*)(alfa romeo)(?:.*)', [responses['alfa romeo']]),
    (r'(?:.*)(alphatauri)(?:.*)', [responses['alphatauri']]),

    # Information about drivers
    (r'(?:.*)(max verstappen)(?:.*)', [responses['max verstappen']]),
    (r'(?:.*)(sergio perez)(?:.*)', [responses['sergio perez']]),
    (r'(?:.*)(lewis hamilton)(?:.*)', [responses['lewis hamilton']]),
    (r'(?:.*)(george russell)(?:.*)', [responses['george russell']]),
    (r'(?:.*)(charles leclerc)(?:.*)', [responses['charles leclerc']]),
    (r'(?:.*)(carlos sainz)(?:.*)', [responses['carlos sainz']]),
    (r'(?:.*)(fernando alonso)(?:.*)', [responses['fernando alonso']]),
    (r'(?:.*)(lance stroll)(?:.*)', [responses['lance stroll']]),
    (r'(?:.*)(lando norris)(?:.*)', [responses['lando norris']]),
    (r'(?:.*)(oscar piastri)(?:.*)', [responses['oscar piastri']]),
    (r'(?:.*)(estaban ocon)(?:.*)', [responses['estaban ocon']]),
    (r'(?:.*)(pierre gasly)(?:.*)', [responses['pierre gasly']]),
    (r'(?:.*)(alex albon)(?:.*)', [responses['alex albon']]),
    (r'(?:.*)(logan sargeant)(?:.*)', [responses['logan sargeant']]),
    (r'(?:.*)(kevin magnussen)(?:.*)', [responses['kevin magnussen']]),
    (r'(?:.*)(nico hulkenberg)(?:.*)', [responses['nico hulkenberg']]),
    (r'(?:.*)(valtteri bottas)(?:.*)', [responses['valtteri bottas']]),
    (r'(?:.*)(guanyu zhou)(?:.*)', [responses['guanyu zhou']]),
    (r'(?:.*)(yuki tsunoda)(?:.*)', [responses['yuki tsunoda']]),
    (r'(?:.*)(daniel ricciardo)(?:.*)', [responses['daniel ricciardo']]),

    # Race information
    (r'(?:.*)(race wins)(?:.*)', [responses['race wins']])
]

chatbot = Chat(patterns, reflections)

def main():
    user_name = input("F1 CHATS: Hello! What's your name? ")
    print("F1 CHATS:", responses["greetings"][0].format(user_name))

    while True:
        user_input = input("{}: ".format(user_name))
        if user_input.lower() == "see ya later":
            print("F1 CHATS: Thank you for using F1CHATS, {}. Goodbye!".format(user_name))
            break
        response = chatbot.respond(user_input)
        print("F1 CHATS:", response.format(user_name))

if __name__ == "__main__":
    main()
# Out:
# F1 CHATS: Hello! What's your name? raj
# F1 CHATS: Hello, raj ! How can I assist you Formula 1 today?
# raj: who has the most race wins in 2023 season
# F1 CHATS: Max verstappen has the most race wins in 2023 -- 10 wins in 13 races
# raj: tell me about team red bull
# F1 CHATS: Established in 2005, Red Bull quickly rose to prominence, securing four consecutive drivers and constructors titles from 2010 to 2013.
# raj: what is a pitstop in f1
# F1 CHATS: Pit stops are crucial in F1 races for changing tires, refueling (although less common now), and making adjustments to the car. Quick and well-coordinated pit stops are vital for a team race strategy.
# raj: how long does a f1 race exist
# F1 CHATS: The length of a Formula 1 race varies, but most races have a total distance of around 305 kilometers (190 miles) and last for approximately 90 to 120 minutes.
# raj: tell me about oscar piastri driver
# ...
